# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.max_columns', None)
folder_path = "casas.csv"
df = pd.read_csv(folder_path)

# %% [markdown]
# ### Atividade de estatistica: Data limite de entrega 06 de maio de 2024.

# %%
df.head()
# Out:
#    ordem  pid  moradia_classe moradia_zoneamento                 lote_fachada  \
# 0      1    1       526301100                 20  Residencial baixa densidade
# 1      2    2       526350040                 20   Residencial alta densidade
# 2      3    3       526351010                 20  Residencial baixa densidade
# 3      4    4       526353030                 20  Residencial baixa densidade
# 4      5    5       527105010                 60  Residencial baixa densidade
#
#    lote_area  rua_tipo    beco_tipo lote_formato     terreno_contorno  \
# 0      141.0     31770  pavimentada          NaN  levemente irregular
# 1       80.0     11622  pavimentada          NaN              regular
# 2       81.0     14267  pavimentada          NaN  levemente irregular
# 3       93.0     11160  pavimentada          NaN              regular
# 4       74.0     13830  pavimentada          NaN  levemente irregular
#
#                        utilidades                        lote_config  \
# ...

# %% [markdown]
# ### 1. Descrever as variáveis envolvidas, tamanho da amostra e se houve a necessidade de fazer alguma filtragem na base de dados.
#
# ##### Para uma descrição das variáveis, vocês devem instalar o pacote dados no R e em seguida rodar os seguintes comandos:
# - library("dados")
# - help("casas")

# %%
df.shape
# Out:
# (2930, 83)

# %% [markdown]
# ### 2. Fazer uma análise descritiva das variáveis envolvidas, incluindo o nível de correlação entre cada variável explicativa e a variável resposta. (Entre as váriaveis quantitativas, as qualitativas servem de fator - exemplo Iris especie).

# %%
# Selecionar apenas as colunas numéricas
numeric_columns = df.select_dtypes(include=['number'])

# Calcular a correlação de Pearson
correlation_matrix = numeric_columns.corr()
correlation_matrix.to_excel("dados-corr.xlsx")
# Out:
# Correlação de Pearson entre variáveis numéricas:

# %% [markdown]
# ### 3. Ajustar o modelo inicial considerando todas as variáveis explicativas e analisar a qualidade deste ajuste.
# O modelo precisa ter a finalidade de calcular alguma coluna de nossa escolha.
# Statics model e sklearn

# %% [markdown]
# ### 4. Através de critérios estatísticos, escolher o melhor modelo que se ajusta a estes dados.

# %% [markdown]
# ### 5. Escolhido o melhor modelo, dividir os dados em duas partes (não necessariamente iguais), sendo uma delas, a base de treino e a outra, a base de teste e, de acordo com algum critério estabelecido, mensurar a acurácia do modelo. Se possível, mensurar outras medidas de desempenho associadas ao desempenho do modelo.
